# %% [markdown]
# # Prédiction de séries temporelles
#
# Peux-t-on faire une prédiction à 5 jours sur un cours boursier ou ici cours du Bitcoin...
#
# ## Partie 1 - par régression
# L'idées est de construire est d'entrainer un réseau d'apprentissage qui regardant les données sur n jours prédit le cours des p suivants.

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt # data visualization

# %%
df = pd.read_csv('bitcoin.csv')

# %%
df.head()
# Out:
#          Date     Open     High      Low    Close  Adj Close     Volume
# 0  2017-01-01   963.66  1003.08   958.70   998.33     998.33  147775008
# 1  2017-01-02   998.62  1031.39   996.70  1021.75    1021.75  222184992
# 2  2017-01-03  1021.60  1044.08  1021.60  1043.84    1043.84  185168000
# 3  2017-01-04  1044.40  1159.42  1044.40  1154.73    1154.73  344945984
# 4  2017-01-05  1156.73  1191.10   910.42  1013.38    1013.38  510199008

# %%
df.columns.values
# Out:
# array(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'],
#       dtype=object)

# %%
df.shape
# Out:
# (1049, 7)

# %%
df_open = pd.DataFrame(df['Open'])

# %%
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

plt.figure(figsize=(8, 6))
plt.plot(df_open, color='g')
plt.title('Bitcoin Prix ouverture', weight='bold', fontsize=16)
plt.xlabel('Time', weight='bold', fontsize=14)
plt.ylabel('USD ($)', weight='bold', fontsize=14)
plt.xticks(weight='bold', fontsize=12, rotation=45)
plt.yticks(weight='bold', fontsize=12)
plt.grid(color = 'y', linewidth = 0.5)

# %% [markdown]
# Création d'une fonction pour déterminer un ensemble d'apprentissage

# %%
def TimeSplit(Data,nin,nout,Targetname):
    # Data dataframe
    # nin nout entier
    # Targetname string
    
    # combien de ligne de sorties
    DataOutSize=Data.shape[0]-nin-nout;
    Labels=Data.columns.values[1:7]; # date en moins
    DataOut=[]
    TargetOut=[]
    for i in range(0,DataOutSize):
        out=[]
        target=[]
        for j in range(0,nin):
            for col in ["Open","Close"]: #Labels[1:7]:
                out.append(Data[col][i+j])
        DataOut.append(out)
        for j in range(0,nout):
            target.append(Data["Open"][i+nin+j])
        TargetOut.append(target)
        
    return DataOut,TargetOut

# %%
nb_know = 25 #nombre de jours d'apprentissage
nb_predict= 5 # nombre de jours prédis
X,Y = TimeSplit(df,nb_know,nb_predict,"Open")

# %% [markdown]
# ## a) scikitlearn
#
# L'apprentissage se fait avec les 800 premiers jours et le test sur les 2049 jours restants

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPRegressor
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %% [markdown]
# Normalisation des données

# %%
scaler = StandardScaler().fit(X)
X=scaler.transform(X)

# %% [markdown]
# On sépare les données en 2 comme on regarde une suite temporelle on ne prend pas un échantillon au hazar,on coupe à un moment donné

# %%
X_train=X[0:800]   ;Y_train=Y[0:800] #set d apprentissage
X_test =X[800:len(X)];Y_test =Y[800:len(X)] # set de test

# %% [markdown]
# Définition et entrainement d'un modèle on se restraint à une seule couche pour éviter un sur-apprentissage

# %%
model_skt = MLPRegressor(solver='lbfgs', verbose =True,
                   hidden_layer_sizes=(7,5), activation= "relu", random_state=263 , max_iter = 10000000, tol=0.0001)

# %%
model_skt.fit(X_train,Y_train)
# Out:
# MLPRegressor(hidden_layer_sizes=(7, 5), max_iter=10000000, random_state=263,
#              solver='lbfgs', verbose=True)

# %% [markdown]
# *Que dire de la précision ?* Utilisons le score R2

# %%
metrics.r2_score(Y_train, model_skt.predict(X_train)) # sur echantillon d'apprentissage
# Out:
# 0.9890653715723795

# %%
metrics.r2_score(Y_test, model_skt.predict(X_test)) # sur echantillon test
# Out:
# 0.8653697941206714

# %% [markdown]
# Le modèle ne semble pas extrêmement bon ou sur-entrainé....

# %%
start=800;
end = 1020;
plt.figure(figsize=(16, 8))
plt.plot(range(start,end),df_open[start:end], color='g')
for i in range(start,end-nb_know):
    plt.plot(range(i+nb_know,i+nb_know+nb_predict),model_skt.predict(X[i:i+1])[0], color='r')
plt.title('scikitlearn : Prédiction (test) à 5 jours (en rouge)', weight='bold', fontsize=16)
plt.xlabel('Time', weight='bold', fontsize=14)
plt.ylabel('USD ($)', weight='bold', fontsize=14)
plt.xticks(weight='bold', fontsize=12, rotation=45)
plt.yticks(weight='bold', fontsize=12)
plt.grid(color = 'y', linewidth = 0.5)

# %% [markdown]
# ## b) Keras https://keras.io/about/
#
# cette partie reproduit la partie précédente avec un autre outil Keras

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import plot_model
from sklearn.metrics import r2_score
import keras.optimizers

# %% [markdown]
# Construction du modèel il est possible d'enchainer différents bloc (réseau) avec même des choix d'interconnection

# %%
model_keras = Sequential()
model_keras.add(Dense(2, input_dim=2*nb_know, activation='relu',name='couche1'))
#model_keras.add(Dense(5, activation='relu',name='couche2'))
model_keras.add(Dense(nb_predict,name='sortie'))
model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_19 (Dense)             (None, 7)                 357
# _________________________________________________________________
# dense_20 (Dense)             (None, 5)                 40
# =================================================================
# Total params: 397
# Trainable params: 397
# Non-trainable params: 0
# _________________________________________________________________

# %%
plot_model(model_keras)

# %% [markdown]
# Etape de compilation
# loss : mse (MeanSquaredError) ref https://keras.io/api/losses/
# optimiser : SGD (Gradient Descent) ref https://keras.io/api/optimizers/

# %%
optimizer = keras.optimizers.SGD(lr=0.1, decay=1e-2, momentum=0.9) # ref https://www.kaggle.com/residentmario/keras-optimizers
model_keras.compile(loss='mse', optimizer=optimizer, metrics=['accuracy'])

# %%
# fit the keras model on the dataset
model_keras.fit(X_train, Y_train, epochs=100, steps_per_epoch=10000, verbose =1, batch_size=1)
# Out:
# Epoch 1/100
# 10000/10000 [==============================] - 21s 2ms/step - loss: 12789821.0000 - accuracy: 0.2554
# Epoch 2/100
# 10000/10000 [==============================] - 22s 2ms/step - loss: 12840559.0000 - accuracy: 0.2890
# Epoch 3/100
# 10000/10000 [==============================] - 20s 2ms/step - loss: 12783374.0000 - accuracy: 0.3098
# Epoch 4/100
# 10000/10000 [==============================] - 21s 2ms/step - loss: 12715507.0000 - accuracy: 0.3148
# Epoch 5/100
# 10000/10000 [==============================] - 22s 2ms/step - loss: 12809194.0000 - accuracy: 0.3182
# Epoch 6/100
# 10000/10000 [==============================] - 23s 2ms/step - loss: 12857795.0000 - accuracy: 0.3292
# Epoch 7/100
# 10000/10000 [==============================] - 22s 2ms/step - loss: 12812896.0000 - accuracy: 0.3344
# Epoch 8/100
# 10000/10000 [==============================] - 22s 2ms/step - loss: 12773143.0000 - accuracy: 0.3330
# Epoch 9/100
# 10000/10000 [==============================] - 21s 2ms/step - loss: 12814642.0000 - accuracy: 0.3339
# Epoch 10/100
# 10000/10000 [==============================] - 22s 2ms/step - loss: 12823874.0000 - accuracy: 0.3329
# Epoch 11/100
# 10000/10000 [==============================] - 22s 2ms/step - loss: 12787028.0000 - accuracy: 0.3335
# Epoch 12/100
# 10000/10000 [==============================] - 19s 2ms/step - loss: 12885243.0000 - accuracy: 0.3334
# Epoch 13/100
# 10000/10000 [==============================] - 23s 2ms/step - loss: 12804080.0000 - accuracy: 0.3352
# Epoch 14/100
# 10000/10000 [==============================] - 22s 2ms/step - loss: 12807660.0000 - accuracy: 0.3333
# Epoch 15/100
# 10000/10000 [==============================] - 22s 2ms/step - loss: 12826558.0000 - accuracy: 0.3339
# Epoch 16/100
# 10000/10000 [==============================] - 21s 2ms/step - loss: 12822467.0000 - accuracy: 0.3349
# Epoch 17/100
# 10000/10000 [==============================] - 22s 2ms/step - loss: 12759449.0000 - accuracy: 0.3340
# Epoch 18/100
# 10000/10000 [==============================] - 20s 2ms/step - loss: 
100
# 10000/10000 [==============================] - 19s 2ms/step - loss: 12770903.0000 - accuracy: 0.3352
# Epoch 71/100
# 10000/10000 [==============================] - 23s 2ms/step - loss: 12819890.0000 - accuracy: 0.3334
# Epoch 72/100
# 10000/10000 [==============================] - 23s 2ms/step - loss: 12791924.0000 - accuracy: 0.3333
# Epoch 73/100
# 10000/10000 [==============================] - 22s 2ms/step - loss: 12831886.0000 - accuracy: 0.3342
# Epoch 74/100
# 10000/10000 [==============================] - 22s 2ms/step - loss: 12789486.0000 - accuracy: 0.3350
# Epoch 75/100
# 10000/10000 [==============================] - 22s 2ms/step - loss: 12763897.0000 - accuracy: 0.3339
# Epoch 76/100
# 10000/10000 [==============================] - 23s 2ms/step - loss: 12713043.0000 - accuracy: 0.3341
# Epoch 77/100
# 10000/10000 [==============================] - 23s 2ms/step - loss: 12726886.0000 - accuracy: 0.3351
# Epoch 78/100
# 10000/10000 [==============================] - 21s 2ms/step - loss: 12787188.0000 - accuracy: 0.3345
# Epoch 79/100
# 10000/10000 [==============================] - 19s 2ms/step - loss: 12780795.0000 - accuracy: 0.3332
# Epoch 80/100
# 10000/10000 [==============================] - 23s 2ms/step - loss: 12835766.0000 - accuracy: 0.3344
# Epoch 81/100
# 10000/10000 [==============================] - 20s 2ms/step - loss: 12740970.0000 - accuracy: 0.3340
# Epoch 82/100
# 10000/10000 [==============================] - 22s 2ms/step - loss: 12797299.0000 - accuracy: 0.3339
# Epoch 83/100
# 10000/10000 [==============================] - 22s 2ms/step - loss: 12793106.0000 - accuracy: 0.3321
# Epoch 84/100
# 10000/10000 [==============================] - 19s 2ms/step - loss: 12788139.0000 - accuracy: 0.3345
# Epoch 85/100
# 10000/10000 [==============================] - 22s 2ms/step - loss: 12747688.0000 - accuracy: 0.3341
# Epoch 86/100
# 10000/10000 [==============================] - 23s 2ms/step - loss: 12745587.0000 - accuracy: 0.3333
# Epoch 87/100
# 10000/10000 [==============================] - 22s 2ms/step - loss: 12826018.0000 - accuracy: 0.3338
# Epoch 88/100
# 10000/10000 [==============================] - 22s 2ms/step - loss: 12845710.0000 - accuracy: 0.3329
# Epoch 89/100
# 10000/10000 [==============================] - 23s 2ms/step - loss: 12800940.0000 - accuracy: 0.3341
# Epoch 90/100
# 10000/10000 [==============================] - 19s 2ms/step - loss: 12790659.0000 - accuracy: 0.3338
# Epoch 91/100
# 10000/10000 [==============================] - 21s 2ms/step - loss: 12789173.0000 - accuracy: 0.3351
# Epoch 92/100
# 10000/10000 [==============================] - 22s 2ms/step - loss: 12764964.0000 - accuracy: 0.3333
# Epoch 93/100
# 10000/10000 [==============================] - 24s 2ms/step - loss: 12773902.0000 - accuracy: 0.3333
# Epoch 94/100
# 10000/10000 [==============================] - 22s 2ms/step - loss: 12772177.0000 - accuracy: 0.3345
# Epoch 95/100
# 10000/10000 [==============================] - 23s 2ms/step - loss: 12765601.0000 - accuracy: 0.3344
# Epoch 96/100
# 10000/10000 [==============================] - 20s 2ms/step - loss: 12782264.0000 - accuracy: 0.3339
# Epoch 97/100
# 10000/10000 [==============================] - 23s 2ms/step - loss: 12834425.0000 - accuracy: 0.3334
# Epoch 98/100
# 10000/10000 [==============================] - 22s 2ms/step - loss: 12837864.0000 - accuracy: 0.3339
# Epoch 99/100
# 10000/10000 [==============================] - 24s 2ms/step - loss: 12813092.0000 - accuracy: 0.3340
# Epoch 100/100
# 10000/10000 [==============================] - 21s 2ms/step - loss: 12875505.0000 - accuracy: 0.3342

# %%
metrics.r2_score(Y_train, model_keras.predict(X_train)) # sur echantillon d'apprentissage
# Out:
# -4.1871079989430625e-06

# %%
metrics.r2_score(Y_test, model_keras.predict(X_test)) # sur echantillon d'apprentissage
# Out:
# -2.7510768778018617

# %%
start=800;
end = 1020;
plt.figure(figsize=(16, 8))
plt.plot(range(start,end),df_open[start:end], color='g')
for i in range(start,end-nb_know):
    plt.plot(range(i+nb_know,i+nb_know+nb_predict),model_keras.predict(X[i:i+1])[0], color='r')
plt.title('Prédiction (test) à 5 jours (en rouge)', weight='bold', fontsize=16)
plt.xlabel('Time', weight='bold', fontsize=14)
plt.ylabel('USD ($)', weight='bold', fontsize=14)
plt.xticks(weight='bold', fontsize=12, rotation=45)
plt.yticks(weight='bold', fontsize=12)
plt.grid(color = 'y', linewidth = 0.5)
